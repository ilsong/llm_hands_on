# %%
def split_heads(x, num_heads, head_dim):
    b, num_tokens, d_out = x.shape
    
    # [문제 4] (batch, num_tokens, d_out) -> (batch, num_heads, num_tokens, head_dim)으로 변환하세요.
    # 1. view를 사용하여 num_heads와 head_dim 차원을 만듭니다.
    # 2. transpose를 사용하여 num_heads 차원을 앞으로 보냅니다.
    
    # x = x.view(...)
    # x = x.transpose(...)
    
    return x # 최종 형태: (b, num_heads, num_tokens, head_dim)

# 검증
d_out, num_heads = 4, 2
head_dim = d_out // num_heads
sample_x = torch.randn(2, 6, 4)
output = split_heads(sample_x, num_heads, head_dim)
print(f"출력 크기: {output.shape}") # (2, 2, 6, 2)가 나와야 함
